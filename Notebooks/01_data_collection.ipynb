# %% [markdown]
# # Imports & setup

# %%
import os
import json
from datetime import datetime
import requests
import pandas as pd

BASE_URL = "https://ghoapi.azureedge.net/api"  # WHO GHO OData API
PROJECT_ROOT = ".."  # adjust if needed

RAW_DIR = os.path.join(PROJECT_ROOT, "data", "raw")
PROCESSED_DIR = os.path.join(PROJECT_ROOT, "data", "processed")

os.makedirs(RAW_DIR, exist_ok=True)
os.makedirs(PROCESSED_DIR, exist_ok=True)

session = requests.Session()
session.headers.update({
    "User-Agent": "who-air-pollution-portfolio/1.0 (data-collection)"
})

print("Folders ready:", RAW_DIR, PROCESSED_DIR)
# Out:
# Folders ready: ../data/raw ../data/processed

# %%
# Cell 2 — Helper: robust GET + pagination for WHO OData

def who_get(url: str, params: dict | None = None, timeout: int = 60) -> dict:
    r = session.get(url, params=params, timeout=timeout)
    r.raise_for_status()
    return r.json()


def fetch_odata_all(endpoint: str, params: dict | None = None, page_size: int = 1000, max_pages: int = 2000) -> list[dict]:
    """
    Fetch all rows from a WHO GHO OData endpoint using $top and $skip pagination.
    endpoint: full URL like f"{BASE_URL}/Indicator" or f"{BASE_URL}/<INDICATOR_CODE>"
    """
    params = dict(params or {})
    params.setdefault("$top", page_size)

    all_rows = []
    skip = 0
    pages = 0

    while True:
        pages += 1
        if pages > max_pages:
            raise RuntimeError("Too many pages — stopping to avoid infinite loop.")

        params["$skip"] = skip
        payload = who_get(endpoint, params=params)
        rows = payload.get("value", [])

        all_rows.extend(rows)

        # stop condition
        if len(rows) < page_size:
            break

        skip += page_size

    return all_rows

# %%
# Cell 3 — Search the indicator catalog to find the RIGHT indicator codes
# Tip: run this first, inspect results, pick your indicator(s)

def search_indicators(keyword: str, top: int = 50) -> pd.DataFrame:
    """
    Search Indicator catalog for keyword in IndicatorName.
    """
    # OData function 'contains' works on many OData services; if it fails,
    # you can fallback to pulling a bigger list and filtering in pandas.
    params = {
        "$filter": f"contains(IndicatorName,'{keyword}')",
        "$select": "IndicatorCode,IndicatorName",
        "$top": top
    }
    rows = fetch_odata_all(f"{BASE_URL}/Indicator", params=params, page_size=min(top, 1000))
    return pd.DataFrame(rows).sort_values("IndicatorName").reset_index(drop=True)

# Try a few searches:
df_pm = search_indicators("particulate", top=50)
df_air = search_indicators("air pollution", top=50)
df_air
# Out:
# {'@odata.context': 'https://ghoapi.azureedge.net/api/$metadata#Indicator(IndicatorCode,IndicatorName)', 'value': [{'IndicatorCode': 'OCC_5', 'IndicatorName': 'Occupational airborne particulates attributable deaths'}, {'IndicatorCode': 'OCC_6', 'IndicatorName': "Occupational airborne particulates attributable DALYs ('000)"}, {'IndicatorCode': 'OCC_7', 'IndicatorName': "Occupational airborne particulates attributable deaths per 100'000 capita"}, {'IndicatorCode': 'OCC_8', 'IndicatorName': "Occupational airborne particulates attributable DALYs per 100'000 capita"}, {'IndicatorCode': 'SDGPM25', 'IndicatorName': 'Concentrations of fine particulate matter (PM2.5)'}]}
# {'@odata.context': 'https://ghoapi.azureedge.net/api/$metadata#Indicator(IndicatorCode,IndicatorName)', 'value': [{'IndicatorCode': 'AIR_10', 'IndicatorName': "Ambient air pollution  attributable DALYs per 100'000 children under 5 years"}, {'IndicatorCode': 'AIR_11', 'IndicatorName': 'Household air pollution attributable deaths'}, {'IndicatorCode': 'AIR_12', 'IndicatorName': 'Household air pollution attributable deaths in children under 5 years'}, {'IndicatorCode': 'AIR_13', 'IndicatorName': "Household air pollution attributable deaths per 100'000 capita"}, {'IndicatorCode': 'AIR_14', 'IndicatorName': "Household air pollution  attributable deaths per 100'000 children under 5 years"}, {'IndicatorCode': 'AIR_15', 'IndicatorName': 'Household air pollution attributable DALYs'}, {'IndicatorCode': 'AIR_16', 'IndicatorName': 'Household air pollution attributable DALYs in children under 5 years'}, {'IndicatorCode': 'AIR_17', 'IndicatorName': 'Household air pollution attributable DALYs (per 100 000 population)'}, {'IndicatorCode': 'AIR_18', 'IndicatorName': "Household air pollution  attributable DALYs per 100'000 children under 5 years"}, {'IndicatorCode': 'AIR_35', 'IndicatorName': 'Joint effects of air pollution attributable deaths'}, {'IndicatorCode': 'AIR_36', 'IndicatorName': 'Joint effects of air pollution attributable deaths in children under 5 years'}, {'IndicatorCode': 'AIR_39', 'IndicatorName': 'Household air pollution attributable DALYs (per 100 000, age-standardized)'}, {'IndicatorCode': 'AIR_4', 'IndicatorName': 'Ambient air pollution attributable deaths in children under 5 years'}, {'IndicatorCode': 'AIR_41', 'IndicatorName': 'Ambient air pollution attributable deaths'}, {'IndicatorCode': 'AIR_42', 'IndicatorName': 'Ambient air pollution attributable death rate (per 100 000 population, age-standardized)'}, {'IndicatorCode': 'AIR_43', 'IndicatorName': 'Ambient air pollution attributable DALYs'}, {'IndicatorCode': 'AIR_44', 'IndicatorName': 'DALYs attributable to ambient air pollution (age-standardized)'}, {'IndicatorCode': 'AIR_45', 'IndicatorName': 'Ambient air pollution attributable YLLs'}, {'IndicatorCode': 'AIR_46', 'IndicatorName': 'YLLs attributable to ambient air pollution (age-standardized)'}, {'IndicatorCode': 'AIR_5', 'IndicatorName': 'Ambient air pollution attributable death rate (per 100 000 population)'}, {'IndicatorCode': 'AIR_50', 'IndicatorName': 'Ambient air pollution attributable deaths (per 100 000 population, age-standardized)'}, {'IndicatorCode': 'AIR_51', 'IndicatorName': 'Household air pollution attributable death rate (per 100 000 population)'}, {'IndicatorCode': 'AIR_52', 'IndicatorName': 'Household air pollution attributable death rate (per 100 000 population, age-standardized)'}, {'IndicatorCode': 'AIR_6', 'IndicatorName': "Ambient air pollution  attributable deaths per 100'000 children under 5 years"}, {'IndicatorCode': 'AIR_60', 'IndicatorName': 'Household and ambient air pollution attributable DALYs'}, {'IndicatorCode': 'AIR_61', 'IndicatorName': 'Household and ambient air pollution attributable DALYs (per 100 000 capita)'}, {'IndicatorCode': 'AIR_62', 'IndicatorName': 'Household and ambient air pollution attributable DALYs (per 100 000 capita, age-standardized)'}, {'IndicatorCode': 'AIR_63', 'IndicatorName': "Household and ambient air pollution attributable DALYs in children under 5 years ('000)"}, {'IndicatorCode': 'AIR_7', 'IndicatorName': 'Ambient air pollution attributable DALYs'}, {'IndicatorCode': 'AIR_71', 'IndicatorName': 'Ambient air pollution attributable DALYs in children under 15 years'}, {'IndicatorCode': 'AIR_72', 'IndicatorName': 'Ambient air pollution attributable deaths in children under 15 years'}, {'IndicatorCode': 'AIR_73', 'IndicatorName': 'Ambient air pollution attributable YLL in children under 15 years'}, {'IndicatorCode': 'AIR_74', 'IndicatorName': 'Household air pollution attributable deaths in children under 15 years'}, {'IndicatorCode': 'AIR_75', 'IndicatorName': ' ...
#    IndicatorCode                                      IndicatorName
# 0         AIR_10  Ambient air pollution  attributable DALYs per ...
# 1          AIR_6  Ambient air pollution  attributable deaths per...
# 2          AIR_7           Ambient air pollution attributable DALYs
# 3         AIR_43           Ambient air pollution attributable DALYs
# 4          AIR_9  Ambient air pollution attributable DALYs  (per...
# 5         AIR_90  Ambient air pollution attributable DALYs  (per...
# 6          AIR_8  Ambient air pollution attributable DALYs  in c...
# 7         AIR_71  Ambient air pollution attributable DALYs in ch...
# 8         AIR_73  Ambient air pollution attributable YLL in chil...
# 9         AIR_45            Ambient air pollution attributable YLLs
# 10         AIR_5  Ambient air pollution attributable death rate ...
# 11        AIR_42  Ambient air pollution attributable death rate ...
# 12        AIR_41          Ambient air pollution attributable deaths
# 13        AIR_50  Ambient air pollution attributable deaths (per...
# 14        AIR_72  Ambient air pollution attributable deaths in c...
# 15         AIR_4  Ambient air pollution attributable deaths in c...
# 16     SDGAIRBOD  Ambient and household air pollution attributab...
# 17    SDGAIRBODA  Ambient and household air pollution attributab...
# 18        AIR_44  DALYs attributable to ambient air pollution (a...
# 19        AIR_18  Household air pollution  attributable DALYs pe...
# 20        AIR_14  Household air pollution  attributable deaths p...
# 21        AIR_15         Household air pollution attributable DALYs
# 22        AIR_17  Household air pollution attributable DALYs (pe...
# 23        AIR_39  Household air pollution attributable DALYs (pe...
# 24        AIR_75  Household air pollution attributable DALYs in ...
# 25        AIR_16  Household air pollution attributable DALYs in ...
# 26        AIR_51  Household air pollution attributable death rat...
# 27        AIR_52  Household air pollution attributable death rat...
# 28        AIR_11        Household air pollution attributable deaths
# 29        AIR_74  Household air pollution attributable deaths in...
# 30        AIR_12  Household air pollution attributable deaths in...
# 31        AIR_13  Household air pollution attributable deaths pe...
# 32        AIR_60  Household and ambient air pollution attributab...
# 33        AIR_61  Household and ambient air pollution attributab...
# 34        AIR_62  Household and ambient air pollution attributab...
# 35        AIR_63  Household and ambient air pollution attributab...
# 36        AIR_35  Joint effects of air pollution attributable de...
# 37        AIR_36  Joint effects of air pollution attributable de...
# 38        AIR_46  YLLs attributable to ambient air pollution (ag...
